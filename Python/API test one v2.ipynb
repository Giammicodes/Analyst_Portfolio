# %%
import requests
import json

# Overwatch League API request
access_token = "EUM7WfToMJYdKNx3Cd0gD6HL7yLf6Z7AZh"
owl_url = "https://us.api.blizzard.com/owl/v1/owl2"
owl_headers = {"Authorization": f"Bearer {access_token}"}

owl_response = requests.get(owl_url, headers=owl_headers)
owl_data = owl_response.json()

# Now you can print or further process the 'owl_data' variable
print("Overwatch League data:")
print(owl_data)
# Out:
# Overwatch League data:
# ...

# %%
import requests
import pandas as pd

# Overwatch League API request
access_token = "EUM7WfToMJYdKNx3Cd0gD6HL7yLf6Z7AZh"
owl_url = "https://us.api.blizzard.com/owl/v1/owl2"
owl_headers = {"Authorization": f"Bearer {access_token}"}

owl_response = requests.get(owl_url, headers=owl_headers)
owl_data = owl_response.json()

# Normalize the Overwatch League data
normalized_owl_data = pd.json_normalize(owl_data)

# Now you can work with the normalized data
print("Normalized Overwatch League data:")
print(normalized_owl_data)
# Out:
# Normalized Overwatch League data:
#                                      currentSegments futureSegments  \
# 0  [owl2-2023-regular-tournaments-playoffs, owl2-...             []
#
#    players.15396.number  players.15396.preferredSlot players.15396.givenName  \
# 0                    20                            1                Ji Hyeok
#
#                                  players.15396.teams players.15396.name  \
# 0  [{'id': 15252, 'earliestMatch': 1680297300000}...           Birdring
#
#   players.15396.familyName players.15396.competitions players.15396.role  \
# 0                      Kim                     [owl2]            offense
#
#    players.15396.id                          players.15396.headshotUrl  \
# 0             15396  https://images.blz-contentstack.com/v3/assets/...
#
#                           players.15396.alternateIds  \
# 0  [{'competitions': ['owl', 'owl-preseason'], 'i...
#
#    players.15396.currentTeam  players.15401.number  \
# ...

# %%
import requests
import json

# Overwatch League API request
access_token = "EUM7WfToMJYdKNx3Cd0gD6HL7yLf6Z7AZh"
owl_url = "https://us.api.blizzard.com/owl/v1/owl2"
owl_headers = {"Authorization": f"Bearer {access_token}"}

owl_response = requests.get(owl_url, headers=owl_headers)
owl_data = owl_response.json()

# Now you can print or further process the 'owl_data' variable
print(owl_data)
# Out:
# {'players': {'15396': {'number': 20, 'preferredSlot': 1, 'givenName': 'Ji Hyeok', 'teams': [{'id': 15252, 'earliestMatch': 1680297300000}, {'id': 15330}], 'name': 'Birdring', 'familyName': 'Kim', 'competitions': ['owl2'], 'role': 'offense', 'id': 15396, 'headshotUrl': 'https://images.blz-contentstack.com/v3/assets/blt321317473c90505c/blt39bea5395fd7c591/64337aabbad30b6ff45736ec/Birdring_BostonUprising_600x600.png', 'alternateIds': [{'competitions': ['owl', 'owl-preseason'], 'id': 4656}], 'currentTeam': 15252}, '15401': {'number': 21, 'preferredSlot': 4, 'givenName': 'Gael', 'teams': [{'id': 15169}, {'id': 15170, 'earliestMatch': 1651863600000}, {'id': 15303}, {'id': 15320}, {'id': 15233, 'stats': {}, 'heroes': {}, 'logo': 'https://images.blz-contentstack.com/v3/assets/blt321317473c90505c/bltd0fc420bef229c9c/6397a85931fe6311c0834455/2023_Seoul-Infernal_Icon-Color.png', 'icon': 'https://images.blz-contentstack.com/v3/assets/blt321317473c90505c/bltd166c9e255cb01bb/6397a8597422f110535cfc
# ...

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(owl_data)
# Out:
#                                      currentSegments futureSegments  \
# 0  [owl2-2023-regular-tournaments-playoffs, owl2-...             []
#
#    players.15396.number  players.15396.preferredSlot players.15396.givenName  \
# 0                    20                            1                Ji Hyeok
#
#                                  players.15396.teams players.15396.name  \
# 0  [{'id': 15252, 'earliestMatch': 1680297300000}...           Birdring
#
#   players.15396.familyName players.15396.competitions players.15396.role  \
# 0                      Kim                     [owl2]            offense
#
#    players.15396.id                          players.15396.headshotUrl  \
# 0             15396  https://images.blz-contentstack.com/v3/assets/...
#
#                           players.15396.alternateIds  \
# 0  [{'competitions': ['owl', 'owl-preseason'], 'i...
#
#    players.15396.currentTeam  players.15401.number  \
# 0                      15252                    21
#
# ...
